# %%
# ! pip install -r dreamerv3/requirements.txt -U
! pip install gymnasium[atari]
! pip install gym
! pip install opencv-python
! pip install vizdoom
! pip install torch

# dreamer
! pip install av
! pip install chex
! pip install colored_traceback
! pip install einops
! pip install elements>=3.17.0
! pip install google-resumable-media>=2.7.2
! pip install granular>=0.20.3
! pip install ipdb
! pip install jax[cuda12]==0.4.33
! pip install jaxtyping
# ! pip install ninjax>=3.5.1
! pip install ninjax
! pip install numpy<2  # DMLab: <2, MineRLv1.0: <1.24
! pip install optax
# ! pip install portal>=3.5.0
! pip install portal
# ! pip install scope>=0.4.4
! pip install scope
! pip install tqdm
! pip install embodied
# ! pip install nvidia-cuda-nvcc-cu12<=12.2
! pip install nvidia-cuda-nvcc-cu12
# Out:
# zsh:1: no matches found: gymnasium[atari]
# Requirement already satisfied: gym in ./.venv/lib/python3.10/site-packages (0.26.2)
# Requirement already satisfied: numpy>=1.18.0 in ./.venv/lib/python3.10/site-packages (from gym) (2.2.1)
# Requirement already satisfied: cloudpickle>=1.2.0 in ./.venv/lib/python3.10/site-packages (from gym) (3.1.0)
# Requirement already satisfied: gym-notices>=0.0.4 in ./.venv/lib/python3.10/site-packages (from gym) (0.0.8)
#
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: opencv-python in ./.venv/lib/python3.10/site-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in ./.venv/lib/python3.10/site-packages (from opencv-python) (2.2.1)
#
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: vizdoom in ./.venv/lib/python3.10/site-packages (1.2.4)
# Requirement already satisfied: numpy in ./.venv/lib/python3.10/site-packages (from vizdoom) (2.2.1)
# Requirement already satisfied: gymnasium>=0.28.0 in ./.venv/lib/python3.10/site-packages (from vizdoom) (1.0.0)
# Requirement already satisfied: pygame>=2.1.3 in ./.venv/lib/python3.10/site-packages (from vizdoom) (2.6.1)
# Requirement already satisfied: cloudpickle>=1.2.0 in ./.venv/lib/python3.10/site-packages (from gymnasium>=0.28.0->vizdoom) (3.1.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in ./.venv/lib/python3.10/site-packages (from gymnasium>=0.28.0->vizdoom) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in ./.venv/lib/python3.10/site-packages (from gymnasium>=0.28.0->vizdoom) (0.0.4)
#
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: torch in ./.venv/lib/python3.10/site-packages (2.5.1)
# Requirement already satisfied: filelock in ./.venv/lib/python3.10/site-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in ./.venv/lib/python3.10/site-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in ./.venv/lib/python3.10/site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in ./.venv/lib/python3.10/site-packages (from torch) (3.1.5)
# Requirement already satisfied: fsspec in ./.venv/lib/python3.10/site-packages (from torch) (2024.12.0)
# Requirement already satisfied: sympy==1.13.1 in ./.venv/lib/python3.10/site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./.venv/lib/python3.10/site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.venv/lib/python3.10/site-packages (from jinja2->torch) (3.0.2)
#
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: av in ./.venv/lib/python3.10/site-packages (14.0.1)
#
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: chex in ./.venv/lib/python3.10/site-packages (0.1.88)
# Requirement already satisfied: absl-py>=0.9.0 in ./.venv/lib/python3.10/site-packages (from chex) (2.1.0)
# Requirement already satisfied: typing_extensions>=4.2.0 in ./.venv/lib/python3.10/site-packages (from chex) (4.12.2)
# Requirement already satisfied: jax>=0.4.27 in ./.venv/lib/python3.10/site-packages (from chex) (0.4.38)
# Requirement already satisfied: jaxlib>=0.4.27 in ./.venv/lib/python3.10/site-packages (from chex) (0.4.38)
# Requirement already satisfied: numpy>=1.24.1 in ./.venv/lib/python3.10/site-packages (from chex) (2.2.1)
# Requirement already satisfied: toolz>=0.9.0 in ./.venv/lib/python3.10/site-packages (from chex) (1.0.0)
# Requirement already satisfied: ml_dtypes>=0.4.0 in ./.venv/lib/python3.10/site-packages (from jax>=0.4.27->chex) (0.5.1)
# Requirement already satisfied: opt_einsum in ./.venv/lib/python3.10/site-packages (from jax>=0.4.27->chex) (3.4.0)
# Requirement already satisfied: scipy>=1.10 in ./.venv/lib/python3.10/site-packages (from jax>=0.4.27->chex) (1.15.0)
#
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: colored_traceback in ./.venv/lib/python3.10/site-packages (0.4.2)
# Requirement already satisfied: pygments in ./.venv/lib/python3.10/site-packages (from colored_traceback) (2.19.1)
#
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: einops in ./.venv/lib/python3.10/site-packages (0.8.0)
#
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# zsh:1: 3.17.0 not found
# zsh:1: 2.7.2 not found
# zsh:1: 0.20.3 not found
# Requirement already satisfied: ipdb in ./.venv/lib/python3.10/site-packages (0.13.13)
# Requirement already satisfied: ipython>=7.31.1 in ./.venv/lib/python3.10/site-packages (from ipdb) (8.31.0)
# Requirement already satisfied: tomli in ./.venv/lib/python3.10/site-packages (from ipdb) (2.2.1)
# Requirement already satisfied: decorator in ./.venv/lib/python3.10/site-packages (from ipdb) (5.1.1)
# Requirement already satisfied: exceptiongroup in ./.venv/lib/python3.10/site-packages (from ipython>=7.31.1->ipdb) (1.2.2)
# Requirement already satisfied: jedi>=0.16 in ./.venv/lib/python3.10/site-packages (from ipython>=7.31.1->ipdb) (0.19.2)
# Requirement already satisfied: matplotlib-inline in ./.venv/lib/python3.10/site-packages (from ipython>=7.31.1->ipdb) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in ./.venv/lib/python3.10/site-packages (from ipython>=7.31.1->ipdb) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in ./.venv/lib/python3.10/site-packages (from ipython>=7.31.1->ipdb) (3.0.48)
# Requirement already satisfied: pygments>=2.4.0 in ./.venv/lib/python3.10/site-packages (from ipython>=7.31.1->ipdb) (2.19.1)
# Requirement already satisfied: stack_data in ./.venv/lib/python3.10/site-packages (from ipython>=7.31.1->ipdb) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in ./.venv/lib/python3.10/site-packages (from ipython>=7.31.1->ipdb) (5.14.3)
# Requirement already satisfied: typing_extensions>=4.6 in ./.venv/lib/python3.10/site-packages (from ipython>=7.31.1->ipdb) (4.12.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in ./.venv/lib/python3.10/site-packages (from jedi>=0.16->ipython>=7.31.1->ipdb) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in ./.venv/lib/python3.10/site-packages (from pexpect>4.3->ipython>=7.31.1->ipdb) (0.7.0)
# Requirement already satisfied: wcwidth in ./.venv/lib/python3.10/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.31.1->ipdb) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in ./.venv/lib/python3.10/site-packages (from stack_data->ipython>=7.31.1->ipdb) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in ./.venv/lib/python3.10/site-packages (from stack_data->ipython>=7.31.1->ipdb) (3.0.0)
# Requirement already satisfied: pure-eval in ./.venv/lib/python3.10/site-packages (from stack_data->ipython>=7.31.1->ipdb) (0.2.3)
#
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# zsh:1: no matches found: jax[cuda12]==0.4.33
# Requirement already satisfied: jaxtyping in ./.venv/lib/python3.10/site-packages (0.2.36)
#
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# Collecting ninjax
#   Using cached ninjax-3.5.1.tar.gz (17 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: jax in ./.venv/lib/python3.10/site-packages (from ninjax) (0.4.38)
# Requirement already satisfied: jaxlib<=0.4.38,>=0.4.38 in ./.venv/lib/python3.10/site-packages (from jax->ninjax) (0.4.38)
# Requirement already satisfied: ml_dtypes>=0.4.0 in ./.venv/lib/python3.10/site-packages (from jax->ninjax) (0.5.1)
# Requirement already satisfied: numpy>=1.24 in ./.venv/lib/python3.10/site-packages (from jax->ninjax) (2.2.1)
# Requirement already satisfied: opt_einsum in ./.venv/lib/python3.10/site-packages (from jax->ninjax) (3.4.0)
# Requirement already satisfied: scipy>=1.10 in ./.venv/lib/python3.10/site-packages (from jax->ninjax) (1.15.0)
# Building wheels for collected packages: ninjax
#   Building wheel for ninjax (pyproject.toml) ... done
#   Created wheel for ninjax: filename=ninjax-3.5.1-py3-none-any.whl size=11469 sha256=439af72daceb0196aaec87f50020648ca58eeecc64d6b851244136df0f2ff69a
#   Stored in directory: /Users/hiroshinonaka/Library/Caches/pip/wheels/9e/43/4f/e8b4062f1fa0fd2c68c447edf3d7561d17c75cd6ceb86e30a7
# Successfully built ninjax
# Installing collected packages: ninjax
# Successfully installed ninjax-3.5.1
#
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# zsh:1: no such file or directory: 2
# Requirement already satisfied: optax in ./.venv/lib/python3.10/site-packages (0.2.4)
# Requirement already satisfied: absl-py>=0.7.1 in ./.venv/lib/python3.10/site-packages (from optax) (2.1.0)
# Requirement already satisfied: chex>=0.1.87 in ./.venv/lib/python3.10/site-packages (from optax) (0.1.88)
# Requirement already satisfied: jax>=0.4.27 in ./.venv/lib/python3.10/site-packages (from optax) (0.4.38)
# Requirement already satisfied: jaxlib>=0.4.27 in ./.venv/lib/python3.10/site-packages (from optax) (0.4.38)
# Requirement already satisfied: numpy>=1.18.0 in ./.venv/lib/python3.10/site-packages (from optax) (2.2.1)
# Requirement already satisfied: etils[epy] in ./.venv/lib/python3.10/site-packages (from optax) (1.11.0)
# Requirement already satisfied: typing_extensions>=4.2.0 in ./.venv/lib/python3.10/site-packages (from chex>=0.1.87->optax) (4.12.2)
# Requirement already satisfied: toolz>=0.9.0 in ./.venv/lib/python3.10/site-packages (from chex>=0.1.87->optax) (1.0.0)
# Requirement already satisfied: ml_dtypes>=0.4.0 in ./.venv/lib/python3.10/site-packages (from jax>=0.4.27->optax) (0.5.1)
# Requirement already satisfied: opt_einsum in ./.venv/lib/python3.10/site-packages (from jax>=0.4.27->optax) (3.4.0)
# Requirement already satisfied: scipy>=1.10 in ./.venv/lib/python3.10/site-packages (from jax>=0.4.27->optax) (1.15.0)
#
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: portal in ./.venv/lib/python3.10/site-packages (3.5.1)
# Requirement already satisfied: cloudpickle in ./.venv/lib/python3.10/site-packages (from portal) (3.1.0)
# Requirement already satisfied: msgpack in ./.venv/lib/python3.10/site-packages (from portal) (1.1.0)
# Requirement already satisfied: numpy in ./.venv/lib/python3.10/site-packages (from portal) (2.2.1)
# Requirement already satisfied: psutil in ./.venv/lib/python3.10/site-packages (from portal) (6.1.1)
#
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# Collecting scope
#   Downloading scope-0.5.1.tar.gz (491 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.0/491.0 kB 10.0 MB/s eta 0:00:0000:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: av in ./.venv/lib/python3.10/site-packages (from scope) (14.0.1)
# Requirement already satisfied: elements>=3.16.6 in ./.venv/lib/python3.10/site-packages (from scope) (3.17.0)
# Collecting fastapi (from scope)
#   Downloading fastapi-0.115.6-py3-none-any.whl.metadata (27 kB)
# Requirement already satisfied: numpy in ./.venv/lib/python3.10/site-packages (from scope) (2.2.1)
# Collecting pillow (from scope)
#   Downloading pillow-11.1.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (9.1 kB)
# Collecting uvicorn[standard] (from scope)
#   Downloading uvicorn-0.34.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: google-auth in ./.venv/lib/python3.10/site-packages (from elements>=3.16.6->scope) (2.37.0)
# Requirement already satisfied: google-cloud-storage in ./.venv/lib/python3.10/site-packages (from elements>=3.16.6->scope) (2.19.0)
# Requirement already satisfied: psutil in ./.venv/lib/python3.10/site-packages (from elements>=3.16.6->scope) (6.1.1)
# Requirement already satisfied: ruamel.yaml in ./.venv/lib/python3.10/site-packages (from elements>=3.16.6->scope) (0.18.10)
# Collecting starlette<0.42.0,>=0.40.0 (from fastapi->scope)
#   Downloading starlette-0.41.3-py3-none-any.whl.metadata (6.0 kB)
# Collecting pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 (from fastapi->scope)
#   Downloading pydantic-2.10.5-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: typing-extensions>=4.8.0 in ./.venv/lib/python3.10/site-packages (from fastapi->scope) (4.12.2)
# Collecting click>=7.0 (from uvicorn[standard]->scope)
#   Using cached click-8.1.8-py3-none-any.whl.metadata (2.3 kB)
# Collecting h11>=0.8 (from uvicorn[standard]->scope)
#   Using cached h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting httptools>=0.6.3 (from uvicorn[standard]->scope)
#   Downloading httptools-0.6.4-cp310-cp310-macosx_11_0_arm64.whl.metadata (3.6 kB)
# Collecting python-dotenv>=0.13 (from uvicorn[standard]->scope)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Collecting pyyaml>=5.1 (from uvicorn[standard]->scope)
#   Downloading PyYAML-6.0.2-cp310-cp310-macosx_11_0_arm64.whl.metadata (2.1 kB)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0 (from uvicorn[standard]->scope)
#   Downloading uvloop-0.21.0-cp310-cp310-macosx_10_9_universal2.whl.metadata (4.9 kB)
# Collecting watchfiles>=0.13 (from uvicorn[standard]->scope)
#   Downloading watchfiles-1.0.3-cp310-cp310-macosx_11_0_arm64.whl.metadata (4.9 kB)
# Collecting websockets>=10.4 (from uvicorn[standard]->scope)
#   Downloading websockets-14.1-cp310-cp310-macosx_11_0_arm64.whl.metadata (6.7 kB)
# Collecting annotated-types>=0.6.0 (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi->scope)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.27.2 (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi->scope)
#   Downloading pydantic_core-2.27.2-cp310-cp310-macosx_11_0_arm64.whl.metadata (6.6 kB)
# Collecting anyio<5,>=3.4.0 (from starlette<0.42.0,>=0.40.0->fastapi->scope)
#   Using cached anyio-4.8.0-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in ./.venv/lib/python3.10/site-packages (from google-auth->elements>=3.16.6->scope) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in ./.venv/lib/python3.10/site-packages (from google-auth->elements>=3.16.6->scope) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in ./.venv/lib/python3.10/site-packages (from google-auth->elements>=3.16.6->scope) (4.9)
# Requirement already satisfied: google-api-core<3.0.0dev,>=2.15.0 in ./.venv/lib/python3.10/site-packages (from google-cloud-storage->elements>=3.16.6->scope) (2.24.0)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in ./.venv/lib/python3.10/site-packages (from google-cloud-storage->elements>=3.16.6->scope) (2.4.1)
# Requirement already satisfied: google-resumable-media>=2.7.2 in ./.venv/lib/python3.10/site-packages (from google-cloud-storage->elements>=3.16.6->scope) (2.7.2)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in ./.venv/lib/python3.10/site-packages (from google-cloud-storage->elements>=3.16.6->scope) (2.32.3)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in ./.venv/lib/python3.10/site-packages (from google-cloud-storage->elements>=3.16.6->scope) (1.6.0)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in ./.venv/lib/python3.10/site-packages (from ruamel.yaml->elements>=3.16.6->scope) (0.2.12)
# Requirement already satisfied: exceptiongroup>=1.0.2 in ./.venv/lib/python3.10/site-packages (from anyio<5,>=3.4.0->starlette<0.42.0,>=0.40.0->fastapi->scope) (1.2.2)
# Requirement already satisfied: idna>=2.8 in ./.venv/lib/python3.10/site-packages (from anyio<5,>=3.4.0->starlette<0.42.0,>=0.40.0->fastapi->scope) (3.10)
# Collecting sniffio>=1.1 (from anyio<5,>=3.4.0->starlette<0.42.0,>=0.40.0->fastapi->scope)
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in ./.venv/lib/python3.10/site-packages (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage->elements>=3.16.6->scope) (1.66.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0.dev0,>=3.19.5 in ./.venv/lib/python3.10/site-packages (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage->elements>=3.16.6->scope) (5.29.3)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in ./.venv/lib/python3.10/site-packages (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage->elements>=3.16.6->scope) (1.25.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in ./.venv/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth->elements>=3.16.6->scope) (0.6.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.10/site-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage->elements>=3.16.6->scope) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.10/site-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage->elements>=3.16.6->scope) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.10/site-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage->elements>=3.16.6->scope) (2024.12.14)
# Downloading fastapi-0.115.6-py3-none-any.whl (94 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.8/94.8 kB 9.0 MB/s eta 0:00:00
# Downloading pillow-11.1.0-cp310-cp310-macosx_11_0_arm64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 24.9 MB/s eta 0:00:0000:0100:01
# Using cached click-8.1.8-py3-none-any.whl (98 kB)
# Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Downloading httptools-0.6.4-cp310-cp310-macosx_11_0_arm64.whl (103 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.3/103.3 kB 6.6 MB/s eta 0:00:00
# Downloading pydantic-2.10.5-py3-none-any.whl (431 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 431.4/431.4 kB 26.6 MB/s eta 0:00:00
# Downloading pydantic_core-2.27.2-cp310-cp310-macosx_11_0_arm64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 11.2 MB/s eta 0:00:0000:0100:01
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading PyYAML-6.0.2-cp310-cp310-macosx_11_0_arm64.whl (171 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 171.8/171.8 kB 10.2 MB/s eta 0:00:00
# Downloading starlette-0.41.3-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.2/73.2 kB 5.2 MB/s eta 0:00:00
# Downloading uvloop-0.21.0-cp310-cp310-macosx_10_9_universal2.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 9.8 MB/s eta 0:00:00ta 0:00:01
# Downloading watchfiles-1.0.3-cp310-cp310-macosx_11_0_arm64.whl (384 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 384.8/384.8 kB 7.3 MB/s eta 0:00:00a 0:00:01
# Downloading websockets-14.1-cp310-cp310-macosx_11_0_arm64.whl (159 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.9/159.9 kB 6.9 MB/s eta 0:00:00
# Downloading uvicorn-0.34.0-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 3.1 MB/s eta 0:00:00
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached anyio-4.8.0-py3-none-any.whl (96 kB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Building wheels for collected packages: scope
#   Building wheel for scope (pyproject.toml) ... done
#   Created wheel for scope: filename=scope-0.5.1-py3-none-any.whl size=491707 sha256=7b8c0bb9815844448939beb720dca3ba1d4c78f758f42d2ee37f00f2e7d870d7
#   Stored in directory: /Users/hiroshinonaka/Library/Caches/pip/wheels/6f/22/c5/c18ed51910aa5045cf8951a901c82cc4e8218b23994412a8e4
# Successfully built scope
# Installing collected packages: websockets, uvloop, sniffio, pyyaml, python-dotenv, pydantic-core, pillow, httptools, h11, click, annotated-types, uvicorn, pydantic, anyio, watchfiles, starlette, fastapi, scope
# Successfully installed annotated-types-0.7.0 anyio-4.8.0 click-8.1.8 fastapi-0.115.6 h11-0.14.0 httptools-0.6.4 pillow-11.1.0 pydantic-2.10.5 pydantic-core-2.27.2 python-dotenv-1.0.1 pyyaml-6.0.2 scope-0.5.1 sniffio-1.3.1 starlette-0.41.3 uvicorn-0.34.0 uvloop-0.21.0 watchfiles-1.0.3 websockets-14.1
#
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: tqdm in ./.venv/lib/python3.10/site-packages (4.67.1)
#
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# Collecting nvidia-cuda-nvcc-cu12
#   Using cached nvidia-cuda-nvcc-cu12-0.0.1.dev5.tar.gz (4.3 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... error
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [28 lines of output]
#       Traceback (most recent call last):
#         File "/Users/hiroshinonaka/Documents/MyProjects/world_model_language/.venv/lib/python3.10/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 353, in <module>
#           main()
#         File "/Users/hiroshinonaka/Documents/MyProjects/world_model_language/.venv/lib/python3.10/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 335, in main
#           json_out['return_val'] = hook(**hook_input['kwargs'])
#         File "/Users/hiroshinonaka/Documents/MyProjects/world_model_language/.venv/lib/python3.10/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 118, in get_requires_for_build_wheel
#           return hook(config_settings)
#         File "/private/var/folders/cg/q7r_qlms025fx_yyw2tzxqy40000gn/T/pip-build-env-mu1b15to/overlay/lib/python3.10/site-packages/setuptools/build_meta.py", line 334, in get_requires_for_build_wheel
#           return self._get_build_requires(config_settings, requirements=[])
#         File "/private/var/folders/cg/q7r_qlms025fx_yyw2tzxqy40000gn/T/pip-build-env-mu1b15to/overlay/lib/python3.10/site-packages/setuptools/build_meta.py", line 304, in _get_build_requires
#           self.run_setup()
#         File "/private/var/folders/cg/q7r_qlms025fx_yyw2tzxqy40000gn/T/pip-build-env-mu1b15to/overlay/lib/python3.10/site-packages/setuptools/build_meta.py", line 522, in run_setup
#           super().run_setup(setup_script=setup_script)
#         File "/private/var/folders/cg/q7r_qlms025fx_yyw2tzxqy40000gn/T/pip-build-env-mu1b15to/overlay/lib/python3.10/site-packages/setuptools/build_meta.py", line 320, in run_setup
#           exec(code, locals())
#         File "<string>", line 152, in <module>
#       RuntimeError:
#       ###########################################################################################
#       The package you are trying to install is only a placeholder project on PyPI.org repository.
#       This package is hosted on NVIDIA Python Package Index.
#
#       This package can be installed as:
#       ```
#       $ pip install nvidia-pyindex
#       $ pip install nvidia-cuda-nvcc-cu12
#       ```
#       ###########################################################################################
#
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: subprocess-exited-with-error
#
# × Getting requirements to build wheel did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.
#
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
import gymnasium as gym
from vizdoom import gymnasium_wrapper
import numpy as np
import torch
from collections import deque
import utils
import os
import pathlib
import elements
import portal
import yaml

# DreamerV3

import importlib
import os
import pathlib
import sys
from functools import partial as bind

folder = pathlib.Path(__file__).parent
sys.path.insert(0, str(folder.parent))
sys.path.insert(1, str(folder.parent.parent))
__package__ = folder.name

import elements
import numpy as np
import portal
import ruamel.yaml as yaml


# Local Modules

path = os.path.abspath(os.curdir) + "/dreamerv3"
if path not in os.sys.path:
    os.sys.path.append(os.getcwd())
    os.sys.path.append(os.getcwd() + "/dreamerv3")

print(os.sys.path)
# for _ in range(2):
#     os.sys.path.pop(-1)
print(os.getcwd())

from dreamerv3.agent import Agent
from dreamerv3 import main as dreamer_main

from dreamerv3.
# Out:
# ['/opt/homebrew/Cellar/python@3.10/3.10.14/Frameworks/Python.framework/Versions/3.10/lib/python310.zip', '/opt/homebrew/Cellar/python@3.10/3.10.14/Frameworks/Python.framework/Versions/3.10/lib/python3.10', '/opt/homebrew/Cellar/python@3.10/3.10.14/Frameworks/Python.framework/Versions/3.10/lib/python3.10/lib-dynload', '', '/Users/hiroshinonaka/Documents/MyProjects/world_model_language/.venv/lib/python3.10/site-packages', '/Users/hiroshinonaka/Documents/MyProjects/world_model_language', '/Users/hiroshinonaka/Documents/MyProjects/world_model_language/dreamerv3']
# /Users/hiroshinonaka/Documents/MyProjects/world_model_language

# %% [markdown]
# # 1. Setup

# %%
# !nvidia-smi

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# create env

train_config:dict = utils.load_config("config.json")

env = gym.make("VizdoomBasic-v0")
env = dreamer_main.wrap_env(env)
env = utils.wrap_env(env, train_config['training'])

train_config['training'].update('observation_shape', env.observation_space.shape)
train_config['training'].update('action_shape', env.action_space.shape)
# Out:
# /Users/hiroshinonaka/Documents/MyProjects/world_model_language/.venv/lib/python3.10/site-packages/vizdoom/gymnasium_wrapper/base_gymnasium_env.py:84: UserWarning: Detected screen format CRCGCB. Only RGB24 and GRAY8 are supported in the Gymnasium wrapper. Forcing RGB24.
#   warnings.warn(
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 12
#       9 observation, info = env.reset()
#      11 for _ in range(1000):
# ---> 12    action = policy(observation)  # this is where you would insert your policy
#      13    observation, reward, terminated, truncated, info = env.step(action)
#      15    if terminated or truncated:
#
# NameError: name 'policy' is not defined

# %%
agent = Agent(train_config['observation_shape'], train_config['action_shape'],)

observation, info = env.reset()

for _ in range(1000):
   action = agent(observation)  # this is where you would insert your policy
   observation, reward, terminated, truncated, info = env.step(action)

   if terminated or truncated:
      observation, info = env.reset()

env.close()

# %%
def make_agent(config):
  env = make_env(config, 0)
  notlog = lambda k: not k.startswith('log/')
  obs_space = {k: v for k, v in env.obs_space.items() if notlog(k)}
  act_space = {k: v for k, v in env.act_space.items() if k != 'reset'}
  env.close()
  if config.random_agent:
    return embodied.RandomAgent(obs_space, act_space)
  cpdir = elements.Path(config.logdir)
  cpdir = cpdir.parent if config.replicas > 1 else cpdir
  return Agent(obs_space, act_space, elements.Config(
      **config.agent,
      logdir=config.logdir,
      seed=config.seed,
      jax=config.jax,
      batch_size=config.batch_size,
      batch_length=config.batch_length,
      replay_context=config.replay_context,
      report_length=config.report_length,
      replica=config.replica,
      replicas=config.replicas,
  ))


def make_logger(config):
  step = elements.Counter()
  logdir = config.logdir
  multiplier = config.env.get(config.task.split('_')[0], {}).get('repeat', 1)
  outputs = []
  outputs.append(elements.logger.TerminalOutput(config.logger.filter, 'Agent'))
  for output in config.logger.outputs:
    if output == 'jsonl':
      outputs.append(elements.logger.JSONLOutput(logdir, 'metrics.jsonl'))
      outputs.append(elements.logger.JSONLOutput(
          logdir, 'scores.jsonl', 'episode/score'))
    elif output == 'tensorboard':
      outputs.append(elements.logger.TensorBoardOutput(
          logdir, config.logger.fps))
    elif output == 'expa':
      exp = logdir.split('/')[-4]
      run = '/'.join(logdir.split('/')[-3:])
      proj = 'embodied' if logdir.startswith(('/cns/', 'gs://')) else 'debug'
      outputs.append(elements.logger.ExpaOutput(
          exp, run, proj, config.logger.user, config.flat))
    elif output == 'wandb':
      name = '/'.join(logdir.split('/')[-4:])
      outputs.append(elements.logger.WandBOutput(name))
    elif output == 'scope':
      outputs.append(elements.logger.ScopeOutput(elements.Path(logdir)))
    else:
      raise NotImplementedError(output)
  logger = elements.Logger(step, outputs, multiplier)
  return logger


def make_replay(config, folder, mode='train'):
  batlen = config.batch_length if mode == 'train' else config.report_length
  consec = config.consec_train if mode == 'train' else config.consec_report
  capacity = config.replay.size if mode == 'train' else config.replay.size / 10
  length = consec * batlen + config.replay_context
  assert config.batch_size * length <= capacity

  directory = elements.Path(config.logdir) / folder
  if config.replicas > 1:
    directory /= f'{config.replica:05}'
  kwargs = dict(
      length=length, capacity=int(capacity), online=config.replay.online,
      chunksize=config.replay.chunksize, directory=directory)

  if config.replay.fracs.uniform < 1 and mode == 'train':
    assert config.jax.compute_dtype in ('bfloat16', 'float32'), (
        'Gradient scaling for low-precision training can produce invalid loss '
        'outputs that are incompatible with prioritized replay.')
    recency = 1.0 / np.arange(1, capacity + 1) ** config.replay.recexp
    selectors = embodied.replay.selectors
    kwargs['selector'] = selectors.Mixture(dict(
        uniform=selectors.Uniform(),
        priority=selectors.Prioritized(**config.replay.prio),
        recency=selectors.Recency(recency),
    ), config.replay.fracs)

  return embodied.replay.Replay(**kwargs)


def make_env(config, index, **overrides):
  suite, task = config.task.split('_', 1)
  if suite == 'memmaze':
    from embodied.envs import from_gym
    import memory_maze  # noqa
  ctor = {
      'dummy': 'embodied.envs.dummy:Dummy',
      'gym': 'embodied.envs.from_gym:FromGym',
      'dm': 'embodied.envs.from_dmenv:FromDM',
      'crafter': 'embodied.envs.crafter:Crafter',
      'dmc': 'embodied.envs.dmc:DMC',
      'atari': 'embodied.envs.atari:Atari',
      'atari100k': 'embodied.envs.atari:Atari',
      'dmlab': 'embodied.envs.dmlab:DMLab',
      'minecraft': 'embodied.envs.minecraft:Minecraft',
      'loconav': 'embodied.envs.loconav:LocoNav',
      'pinpad': 'embodied.envs.pinpad:PinPad',
      'langroom': 'embodied.envs.langroom:LangRoom',
      'procgen': 'embodied.envs.procgen:ProcGen',
      'bsuite': 'embodied.envs.bsuite:BSuite',
      'memmaze': lambda task, **kw: from_gym.FromGym(
          f'MemoryMaze-{task}-v0', **kw),
  }[suite]
  if isinstance(ctor, str):
    module, cls = ctor.split(':')
    module = importlib.import_module(module)
    ctor = getattr(module, cls)
  kwargs = config.env.get(suite, {})
  kwargs.update(overrides)
  if kwargs.pop('use_seed', False):
    kwargs['seed'] = hash((config.seed, index)) % (2 ** 32 - 1)
  if kwargs.pop('use_logdir', False):
    kwargs['logdir'] = elements.Path(config.logdir) / f'env{index}'
  env = ctor(task, **kwargs)
  return wrap_env(env, config)


def wrap_env(env, config):
  for name, space in env.act_space.items():
    if not space.discrete:
      env = embodied.wrappers.NormalizeAction(env, name)
  env = embodied.wrappers.UnifyDtypes(env)
  env = embodied.wrappers.CheckSpaces(env)
  for name, space in env.act_space.items():
    if not space.discrete:
      env = embodied.wrappers.ClipAction(env, name)
  return env


def make_stream(config, replay, mode):
  fn = bind(replay.sample, config.batch_size, mode)
  stream = embodied.streams.Stateless(fn)
  stream = embodied.streams.Consec(
      stream,
      length=config.batch_length if mode == 'train' else config.report_length,
      consec=config.consec_train if mode == 'train' else config.consec_report,
      prefix=config.replay_context,
      strict=(mode == 'train'),
      contiguous=True)

  return stream

# %%
# this is a function copied and eddited from dreamerv3/dreamerv3/main.py

def main(argv=None):
  [elements.print(line) for line in Agent.banner]

  configs = elements.Path('dreamerv3/dreamerv3/configs.yaml').read()
  configs = yaml.YAML(typ='safe').load(configs)
  parsed, other = elements.Flags(configs=['defaults']).parse_known(argv)
  config = elements.Config(configs['defaults'])
  for name in parsed.configs:
    config = config.update(configs[name])
  config = elements.Flags(config).parse(other)
  config = config.update(logdir=(
      config.logdir.format(timestamp=elements.timestamp())))

  if 'JOB_COMPLETION_INDEX' in os.environ:
    config = config.update(replica=int(os.environ['JOB_COMPLETION_INDEX']))
  print('Replica:', config.replica, '/', config.replicas)

  logdir = elements.Path(config.logdir)
  print('Logdir:', logdir)
  print('Run script:', config.script)
  if not config.script.endswith(('_env', '_replay')):
    logdir.mkdir()
    config.save(logdir / 'config.yaml')

  def init():
    elements.timer.global_timer.enabled = config.logger.timer

  portal.setup(
      errfile=config.errfile and logdir / 'error',
      clientkw=dict(logging_color='cyan'),
      serverkw=dict(logging_color='cyan'),
      initfns=[init],
      ipv6=config.ipv6,
  )

  args = elements.Config(
      **config.run,
      replica=config.replica,
      replicas=config.replicas,
      logdir=config.logdir,
      batch_size=config.batch_size,
      batch_length=config.batch_length,
      report_length=config.report_length,
      consec_train=config.consec_train,
      consec_report=config.consec_report,
      replay_context=config.replay_context,
  )

  if config.script == 'train':
    embodied.run.train(
        bind(make_agent, config),
        bind(make_replay, config, 'replay'),
        bind(make_env, config),
        bind(make_stream, config),
        bind(make_logger, config),
        args)

  elif config.script == 'train_eval':
    embodied.run.train_eval(
        bind(make_agent, config),
        bind(make_replay, config, 'replay'),
        bind(make_replay, config, 'eval_replay', 'eval'),
        bind(make_env, config),
        bind(make_env, config),
        bind(make_stream, config),
        bind(make_logger, config),
        args)

  elif config.script == 'eval_only':
    embodied.run.eval_only(
        bind(make_agent, config),
        bind(make_env, config),
        bind(make_logger, config),
        args)

  elif config.script == 'parallel':
    embodied.run.parallel.combined(
        bind(make_agent, config),
        bind(make_replay, config, 'replay'),
        bind(make_replay, config, 'replay_eval', 'eval'),
        bind(make_env, config),
        bind(make_env, config),
        bind(make_stream, config),
        bind(make_logger, config),
        args)

  elif config.script == 'parallel_env':
    is_eval = config.replica >= args.envs
    embodied.run.parallel.parallel_env(
        bind(make_env, config), config.replica, args, is_eval)

  elif config.script == 'parallel_envs':
    is_eval = config.replica >= args.envs
    embodied.run.parallel.parallel_envs(
        bind(make_env, config), bind(make_env, config), args)

  elif config.script == 'parallel_replay':
    embodied.run.parallel.parallel_replay(
        bind(make_replay, config, 'replay'),
        bind(make_replay, config, 'replay_eval', 'eval'),
        bind(make_stream, config),
        args)

  else:
    raise NotImplementedError(config.script)
